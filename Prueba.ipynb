# %%
import stratilib as sl

# %%
sl.read_lito('Lito.xlsx')
# Out:
#    Pozo            Fm   Tope   Base  Espesor  Litología Granulometría  \
# 0   NaN         Salto    0.0   20.0       20        100             s
# 1   NaN        Arapey   20.0  120.0      100        500            sf
# 2   NaN   Buena Vista  120.0  240.0      120        200             g
# 3   NaN    Tacuarembó  240.0  290.0       50        490             c
# 4   NaN  San Gregorio  290.0  323.0       33        300           NaN
# 5   NaN          Numo  323.0  334.0       11        600           NaN
# 6   NaN       Mañoque  334.0  344.0       10        200           NaN
# 7   NaN       Tulipán  344.0  372.0       28        500           NaN
# 8   NaN          Tito  372.0  738.0      366        300           NaN
#
#    Estructuras  Fósiles  Descripción  Gran
# 0          NaN      NaN          NaN   0.6
# 1          NaN      NaN          NaN   1.0
# 2          NaN      NaN          NaN   0.9
# 3          NaN      NaN          NaN   0.8
# 4          NaN      NaN          NaN   1.0
# ...

# %%
sl.DICT_GRAN
# Out:
# {'cl': 0.55,
#  's': 0.6,
#  'vf': 0.65,
#  'f': 0.7,
#  'm': 0.75,
#  'c': 0.8,
#  'vc': 0.85,
#  'g': 0.9}
